# %% [markdown]
# # 「同期・引き込み現象について」課題
#
# 蔵本モデルにおいて$N=2$として、$K$に適当なパラメータを定め、ひとつの場合について相空間上に各時刻での位置をプロットしてみよ。定性的にはどのような特徴が見られるか?
#
# 同期している状態と、そうでない状態を見分けるのにはどのような指標が必要と考えられるか?
#
# 上で考えた指標により、様々の$K$の値に対して、長い時間系の時間発展を見たあとに収束するかどうかを確認せよ。特徴的な$K$の値は存在するか?
